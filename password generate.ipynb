# %%
import string
import random
def generate_password(length=12):
    chars=string.ascii_letters + string.digits + string.punctuation
    password=""
    for _ in range(length):
        password+=random.choice(chars)
    return password
print("welcome to the password generation!")
leng=int(input("enter the desired password length (default is 12): ") or 12)
password = generate_password(leng)
print(f"Your generated password is: {password}")
# Out:
# welcome to the password generation!
# enter the desired password length (default is 12):  7
# Your generated password is: oj:5a`i
